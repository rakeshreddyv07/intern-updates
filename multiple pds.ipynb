# %%
import fitz  # it is a part like in pymupdf
from nltk.corpus import wordnet

def find_related_words(word):
    synonyms = set()

    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())

    return synonyms

def search_synonyms_in_pdf(synonyms, pdf_path):
    found_words = {}

    doc = fitz.open(pdf_path)

    for page_number in range(len(doc)):
        page = doc.load_page(page_number)
        page_text = page.get_text()

        paragraphs = page_text.split('\n\n')  #/n/n is like paragraphs
        #.split is for like we are spliting 
        for paragraph_number, paragraph in enumerate(paragraphs):
            for word in synonyms:
                if word.lower() in paragraph.lower():      #.lower we are converting into lower
                    if word not in found_words:
                        found_words[word] = []
                    found_words[word].append((page_number + 1, paragraph_number + 1))        #append is like adding 

    doc.close()

    return found_words
    
def search_in_pdfs(synonyms, pdf_paths):
    results = {}
    for pdf_path in pdf_paths:
        results[pdf_path] = search_synonyms_in_pdf(synonyms, pdf_path)
    return results

def main():
    while True:
        searching_word = input("Enter a word to find synonyms and similar words (or 'done' to exit): ")

        if searching_word.lower() == 'done':
            print("Now we are exiting the program.") #After we are done the code will exit here loop is going to break 
        
            break

        synonyms = find_related_words(searching_word)

        if synonyms:
            print(f"Synonyms and related words of '{searching_word}':")
            print(synonyms)

            pdf_paths = [
                "C:/Users/Rakesh Reddy V/Desktop/test.pdf",
                "C:/Users/Rakesh Reddy V/Desktop/new file.pdf"
            ]
            #given the pdf file path here
            found_in_pdf = search_synonyms_in_pdf(synonyms, pdf_path)

            if found_in_pdf:
                print(f"\nSynonyms found in the PDF:")
                for word, locations in found_in_pdf.items():
                    print(f"'{word}' found in this location:")
                    for page_num, para_num in locations:
                        print(f"  - Page number {page_num}, Paragraph number {para_num}")
            else:
                print("\nNo These are the synonyms found in this  PDF file.")
        else:
            print(f"No synonyms found for '{searching_word}' in WordNet library.")

if __name__ == "__main__":
    main()
# Out:
# Enter a word to find synonyms and similar words (or 'done' to exit):  one
# Synonyms and related words of 'one':
# {'one', 'unitary', 'one_and_only', 'unmatchable', 'unrivalled', 'unity', 'peerless', 'single', 'I', 'i', 'ane', '1', 'unrivaled', 'nonpareil', 'unmatched', 'matchless', 'ace'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 74
#      71             print(f"No synonyms found for '{searching_word}' in WordNet library.")
#      73 if __name__ == "__main__":
# ---> 74     main()
#
# Cell In[17], line 60, in main()
#      55 pdf_paths = [
#      56     "C:/Users/Rakesh Reddy V/Desktop/test.pdf",
#      57     "C:/Users/Rakesh Reddy V/Desktop/new file.pdf"
#      58 ]
#      59 #given the pdf file path here
# ---> 60 found_in_pdf = search_synonyms_in_pdf(synonyms, pdf_path)
#      62 if found_in_pdf:
#      63     print(f"\nSynonyms found in the PDF:")
#
# NameError: name 'pdf_path' is not defined

# %%
import fitz  # PyMuPDF
from nltk.corpus import wordnet

def find_related_words(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

def search_synonyms_in_pdf(synonyms, pdf_path):
    found_words = {}
    doc = fitz.open(pdf_path)

    for page_number in range(len(doc)):
        page = doc.load_page(page_number)
        page_text = page.get_text()
        paragraphs = page_text.split('\n\n')#.split is for like we are spliting 

        for paragraph_number, paragraph in enumerate(paragraphs):
            for word in synonyms:
                if word.lower() in paragraph.lower():   #.lower we are converting into lower
                    if word not in found_words:
                        found_words[word] = []
                    found_words[word].append((page_number + 1, paragraph_number + 1))#append is like adding 

    doc.close()
    return found_words

def search_in_pdfs(synonyms, pdf_paths):
    results = {}
    for pdf_path in pdf_paths:
        results[pdf_path] = search_synonyms_in_pdf(synonyms, pdf_path)
    return results

def main():
    while True:
        searching_word = input("Enter a word to find synonyms and similar words (or 'done' to exit): ")
        if searching_word.lower() == 'done':
            print("Now we are exiting the program.") #After we are done the code will exit here loop is going to break 
            break

        synonyms = find_related_words(searching_word)

        if synonyms:
            print(f"Synonyms and related words of '{searching_word}':")
            print(synonyms)

            pdf_paths = [
                "C:/Users/Rakesh Reddy V/Desktop/test.pdf",
                "C:/Users/Rakesh Reddy V/Desktop/new file.pdf",
                "C:/Users/Rakesh Reddy V/Desktop/sample.pdf"
            ]
            #given the pdf files path here
            found_in_pdfs = search_in_pdfs(synonyms, pdf_paths)

            for pdf_path, found_words in found_in_pdfs.items():
                if found_words:
                    print(f"\nSynonyms found in '{pdf_path}':")
                    for word, locations in found_words.items():
                        print(f"'{word}' found in this location:")
                        for page_num, para_num in locations:
                            print(f"  - Page number {page_num}, Paragraph number {para_num}")
                else:
                    print(f"\nNo synonyms found in '{pdf_path}'.")
        else:
            print(f"No synonyms found for '{searching_word}' in WordNet library.")

if __name__ == "__main__":
    main()
# Out:
# Enter a word to find synonyms and similar words (or 'done' to exit):  one
# Synonyms and related words of 'one':
# {'one', 'unitary', 'one_and_only', 'unmatchable', 'unrivalled', 'unity', 'peerless', 'single', 'I', 'i', 'ane', '1', 'unrivaled', 'nonpareil', 'unmatched', 'matchless', 'ace'}
#
# Synonyms found in 'C:/Users/Rakesh Reddy V/Desktop/test.pdf':
# 'one' found in this location:
#   - Page number 1, Paragraph number 1
# 'unity' found in this location:
#   - Page number 1, Paragraph number 1
# 'I' found in this location:
#   - Page number 1, Paragraph number 1
# 'i' found in this location:
#   - Page number 1, Paragraph number 1
# 'ane' found in this location:
#   - Page number 1, Paragraph number 1
# 'ace' found in this location:
#   - Page number 1, Paragraph number 1
#
# Synonyms found in 'C:/Users/Rakesh Reddy V/Desktop/new file.pdf':
# 'one' found in this location:
#   - Page number 1, Paragraph number 1
#   - Page number 2, Paragraph number 1
# 'I' found in this location:
#   - Page number 1, Paragraph number 1
#   - Page number 2, Paragraph number 1
# 'i' found in this location:
#   - Page number 1, Paragraph number 1
#   - Page number 2, Paragraph number 1
# 'ace' found in this location:
#   - Page number 1, Paragraph number 1
#   - Page number 2, Paragraph number 1
# 'unity' found in this location:
#   - Page number 2, Paragraph number 1
#
# Synonyms found in 'C:/Users/Rakesh Reddy V/Desktop/sample.pdf':
# 'one' found in this location:
#   - Page number 1, Paragraph number 1
# 'I' found in this location:
#   - Page number 1, Paragraph number 1
# 'i' found in this location:
#   - Page number 1, Paragraph number 1
